# %%
import tomotopy as tp

# %%
# code from: https://bab2min.github.io/tomotopy/v0.12.6/en/

mdl = tp.LDAModel(k=20)
for line in open('117s_text_clean.txt'):
    mdl.add_doc(line.strip().split())

# %%
for i in range(0, 100, 10):
    mdl.train(10)
    print('Iteration: {}\tLog-likelihood: {}'.format(i, mdl.ll_per_word))
# Out:
# Iteration: 0	Log-likelihood: -10.05363318804706
# Iteration: 10	Log-likelihood: -9.858915508280269
# Iteration: 20	Log-likelihood: -9.74286356506371
# Iteration: 30	Log-likelihood: -9.658925285328412
# Iteration: 40	Log-likelihood: -9.595007378988052
# Iteration: 50	Log-likelihood: -9.535697199549343
# Iteration: 60	Log-likelihood: -9.48274005619362
# Iteration: 70	Log-likelihood: -9.426581545490277
# Iteration: 80	Log-likelihood: -9.378284773081957
# Iteration: 90	Log-likelihood: -9.331731288012746

# %%
for k in range(mdl.k):
    print('Top 10 words of topic #{}'.format(k))
    print(mdl.get_topic_words(k, top_n=10))
# Out:
# Top 10 words of topic #0
# [('the', 0.068659707903862), ('of', 0.0678030401468277), ('and', 0.024969883263111115), ('to', 0.012879250571131706), ('in', 0.012071261182427406), ('subsection', 0.010465017519891262), ('or', 0.010017216205596924), ('under', 0.009686232544481754), ('with', 0.009666763246059418), ('for', 0.008089723996818066)]
# Top 10 words of topic #1
# [('of', 0.060066431760787964), ('the', 0.059560343623161316), ('a', 0.009752844460308552), ('an', 0.009489256888628006), ('in', 0.009320560842752457), ('all', 0.008867190219461918), ('be', 0.008571972139179707), ('and', 0.008550885133445263), ('amounts', 0.008150232024490833), ('may', 0.007190773729234934)]
# Top 10 words of topic #2
# [('of', 0.04316667467355728), ('the', 0.03680483251810074), ('(1),', 0.00786292552947998), ('multiple', 0.00770611921325326), ('website', 0.007459709886461496), ('development', 0.006429270375519991), ('Small', 0.006026054732501507), ('submits', 0.005398830398917198), ('study', 0.00528682628646493), ('For', 0.00528682628646493)]
# Top 10 words of topic #3
# [('of', 0.058979783207178116), ('the', 0.047165337949991226), ('and', 0.029641900211572647), ('or', 0.022386722266674042), ('a', 0.021501298993825912), ('this', 0.013254974968731403), ('to', 0.0130501389503479), ('that', 0.01170218177139759), ('under', 0.01104141864925623), ('in', 0.011008379980921745)]
# Top 10 words of topic #4
# [('the', 0.05463080480694771), ('to', 0.04452325403690338), ('of', 0.03645624965429306), ('and', 0.028014453127980232), ('in', 0.02470674365758896), ('under', 0.015164360404014587), ('on', 0.014301737770438194), ('by', 0.013807961717247963), ('such', 0.012528900988399982), ('Act', 0.012195750139653683)]
# Top 10 words of topic #5
# [('the', 0.07845806330442429), ('of', 0.05571708083152771), ('or', 0.012566741555929184), ('a', 0.007827774621546268), ('subparagraphs', 0.0065559749491512775), ('by', 0.005904934834688902), ('results', 0.005753530189394951), ('and', 0.0056929681450128555), ('Commission', 0.005465860944241285), ('Secretary', 0.00526903523132205)]
# Top 10 words of topic #6
# [('the', 0.06347797811031342), ('and', 0.05369298905134201), ('of', 0.04592102766036987), ('to', 0.024203119799494743), ('for', 0.020841151475906372), ('in', 0.01953371800482273), ('by', 0.018314484506845474), ('or', 0.018267791718244553), ('a', 0.014361058361828327), ('with', 0.011958910152316093)]
# Top 10 words of topic #7
# [('the', 0.07667236775159836), ('and', 0.04478127881884575), ('to', 0.04356956481933594), ('in', 0.03651341423392296), ('of', 0.034669727087020874), ('or', 0.02444326877593994), ('by', 0.02273537777364254), ('a', 0.01943972148001194), ('such', 0.010059376247227192), ('State', 0.009155812673270702)]
# Top 10 words of topic #8
# [('the', 0.0825166329741478), ('to', 0.04197634384036064), ('and', 0.03820951655507088), ('of', 0.02655003033578396), ('a', 0.02239741012454033), ('in', 0.021588319912552834), ('or', 0.01756429672241211), ('on', 0.014719082973897457), ('section', 0.01396357361227274), ('for', 0.013733169995248318)]
# Top 10 words of topic #9
# [('the', 0.07008221000432968), ('of', 0.04086907580494881), ('and', 0.030760111287236214), ('for', 0.01990089751780033), ('a', 0.01700046844780445), ('in', 0.01593310944736004), ('to', 0.014703326858580112), ('by', 0.010457096621394157), ('under', 0.00969911739230156), ('or', 0.00953669287264347)]
# Top 10 words of topic #10
# [('of', 0.07274945825338364), ('the', 0.0681016817688942), ('and', 0.03169287368655205), ('in', 0.022874997928738594), ('a', 0.019379692152142525), ('to', 0.017916364595294), ('for', 0.010554233565926552), ('this', 0.00970504805445671), ('that', 0.00970504805445671), ('or', 0.008992339484393597)]
# Top 10 words of topic #11
# [('the', 0.05743344873189926), ('of', 0.04729364812374115), ('and', 0.029524121433496475), ('for', 0.02049395814538002), ('to', 0.016560479998588562), ('or', 0.015856433659791946), ('a', 0.01384377758949995), ('under', 0.01262700092047453), ('this', 0.011471446603536606), ('subsection', 0.010698525235056877)]
# Top 10 words of topic #12
# [('the', 0.06131643429398537), ('to', 0.049924228340387344), ('of', 0.03943973034620285), ('and', 0.03516765311360359), ('in', 0.03147434443235397), ('a', 0.024291759356856346), ('or', 0.02051101066172123), ('shall', 0.014910676516592503), ('by', 0.014302758499979973), ('under', 0.013420029543340206)]
# Top 10 words of topic #13
# [('the', 0.06971889734268188), ('of', 0.04819184169173241), ('for', 0.011318896897137165), ('service', 0.00961974449455738), ('and', 0.009499331936240196), ('notice', 0.009245128370821476), ('accordance', 0.008616308681666851), ('or', 0.006917155813425779), ('United', 0.006716468371450901), ('direct', 0.006662951782345772)]
# Top 10 words of topic #14
# [('the', 0.05681856721639633), ('of', 0.04679609090089798), ('and', 0.02928011119365692), ('to', 0.02304108627140522), ('as', 0.016194840893149376), ('a', 0.016008004546165466), ('under', 0.014753526076674461), ('in', 0.01385937724262476), ('or', 0.013445666059851646), ('for', 0.013092010281980038)]
# Top 10 words of topic #15
# [('the', 0.06347855180501938), ('of', 0.04220493882894516), ('a', 0.023633327335119247), ('in', 0.02110714465379715), ('and', 0.020829541608691216), ('to', 0.011057930067181587), ('or', 0.01012333482503891), ('by', 0.00923500582575798), ('an', 0.007791472598910332), ('subparagraph', 0.007643417920917273)]
# Top 10 words of topic #16
# [('the', 0.06799650192260742), ('of', 0.03390679880976677), ('to', 0.019815439358353615), ('in', 0.01311543583869934), ('with', 0.012078410014510155), ('United', 0.009384173899888992), ('that', 0.00906899943947792), ('this', 0.008255645632743835), ('and', 0.007848968729376793), ('grant', 0.007767633069306612)]
# Top 10 words of topic #17
# [('the', 0.07441727817058563), ('of', 0.05594754219055176), ('and', 0.04185359179973602), ('to', 0.02493506297469139), ('a', 0.014921702444553375), ('for', 0.014829093590378761), ('or', 0.0137062082067132), ('this', 0.011703535914421082), ('under', 0.011275218799710274), ('such', 0.011020543985068798)]
# Top 10 words of topic #18
# [('of', 0.04637026786804199), ('the', 0.04447152093052864), ('in', 0.030111614614725113), ('and', 0.027223726734519005), ('to', 0.024201635271310806), ('for', 0.021994713693857193), ('under', 0.01878374256193638), ('or', 0.018301598727703094), ('such', 0.01634817384183407), ('a', 0.015602592378854752)]
# Top 10 words of topic #19
# [('the', 0.05153685435652733), ('of', 0.048052337020635605), ('to', 0.03191519156098366), ('and', 0.026363912969827652), ('for', 0.02047867514193058), ('is', 0.01947679929435253), ('a', 0.016433361917734146), ('with', 0.015047118067741394), ('any', 0.014234274625778198), ('or', 0.013654571957886219)]

# %%
mdl.summary()
# Out:
# <Basic Info>
# | LDAModel (current version: 0.12.7)
# | 1 docs, 2767674 words
# | Total Vocabs: 132815, Used Vocabs: 132815
# | Entropy of words: 7.53844
# | Entropy of term-weighted words: 7.53844
# | Removed Vocabs: <NA>
# |
# <Training Info>
# | Iterations: 100, Burn-in steps: 0
# | Optimization Interval: 10
# | Log-likelihood per word: -9.33173
# |
# <Initial Parameters>
# | tw: TermWeight.ONE
# | min_cf: 0 (minimum collection frequency of words)
# | min_df: 0 (minimum document frequency of words)
# | rm_top: 0 (the number of top words to be removed)
# | k: 20 (the number of topics between 1 ~ 32767)
# | alpha: [0.1] (hyperparameter of Dirichlet distribution for document-topic, given as a single `float` in case of symmetric prior and as a list with length `k` of `float` in case of asymmetric prior.)
# | eta: 0.01 (hyperparameter of Dirichlet distribution for topic-word)
# | seed: 838198606 (random seed)
# | trained in version 0.12.7
# |
# <Parameters>
# | alpha (Dirichlet prior on the per-document topic distributions)
# |  [3.7074351 3.4881103 1.901951  5.129438  5.59113   2.5950232 6.3406425
# |   6.322668  6.0999055 4.4793215 4.507063  4.5393724 7.6008377 2.8937593
# |   5.06098   3.8771133 3.5813968 5.7212496 6.5073853 5.282207 ]
# | eta (Dirichlet prior on the per-topic word distribution)
# |  0.01
# |
# <Topics>
# | #0 (101396) : the of and to in
# | #1 (93517) : of the a an in
# | #2 (43313) : of the (1), multiple website
# | #3 (150012) : of the and or a
# | #4 (166764) : the to of and in
# | #5 (64720) : the of or a subparagraphs
# | #6 (191416) : the and of to for
# | #7 (190136) : the and to in of
# | #8 (185301) : the to and of a
# | #9 (127963) : the of and for a
# | #10 (130563) : of the and in a
# | #11 (129345) : the of and for to
# | #12 (238836) : the to of and in
# | #13 (73415) : the of for service and
# | #14 (148535) : the of and to as
# | #15 (106740) : the of a in and
# | #16 (97030) : the of to in with
# | #17 (171441) : the of and to a
# | #18 (199857) : of the in and to
# | #19 (157374) : the of to and for
# |

# %%
import spacy
from spacy_cleaner import processing, Cleaner

model = spacy.load("en_core_web_sm")

# %%
cleaner = Cleaner(model, processing.remove_stopword_token)

# %%
with open('117s_text_clean.txt', 'r') as f:
    text = f.read()

# %%
cleaner.clean(text)
# Out:
# Cleaning Progress: 100%|████████| 20706436/20706436 [1:33:35<00:00, 3687.08it/s]
# ['b',
#  '"',
#  'C',
#  'o',
#  'n',
#  'g',
#  'r',
#  'e',
#  's',
#  's',
#  '',
#  'o',
#  'n',
#  '',
#  'l',
#  '',
#  'B',
#  '',
#  'l',
#  'l',
#  's',
#  '',
#  '1',
#  '1',
#  '7',
#  't',
#  'h',
#  '',
#  'C',
#  'o',
#  'n',
#  'g',
#  'r',
#  'e',
#  's',
#  's',
#  'F',
#  'r',
#  'o',
#  'm',
#  '',
#  't',
#  'h',
#  'e',
#  '',
#  'U',
#  '.',
#  'S',
#  '.',
#  '',
#  'G',
#  'o',
#  'v',
#  'e',
#  'r',
#  'n',
#  'm',
#  'e',
#  'n',
#  't',
#  '',
#  'P',
#  'u',
#  'b',
#  'l',
#  '',
#  's',
#  'h',
#  '',
#  'n',
#  'g',
#  '',
#  'O',
#  'f',
#  'f',
#  '',
#  'c',
#  'e',
#  'S',
#  '.',
#  '',
#  '5',
#  '2',
#  '4',
#  '2',
#  '',
#  '',
#  'n',
#  't',
#  'r',
#  'o',
#  'd',
#  'u',
#  'c',
#  'e',
#  'd',
#  '',
#  '',
#  'n',
#  '',
#  'S',
#  'e',
#  'n',
#  '',
#  't',
#  'e',
#  '',
#  '(',
#  '',
#  'S',
#  ')',
#  '&',
#  'l',
#  't',
#  ';',
#  'D',
#  'O',
#  'C',
#  '&',
#  'g',
#  't',
#  ';',
#  '1',
#  '1',
#  '7',
#  't',
#  'h',
#  '',
#  'C',
#  'O',
#  'N',
#  'G',
#  'R',
#  'E',
#  'S',
#  'S',
#  '2',
#  'd',
#  '',
#  'S',
#  'e',
#  's',
#  's',
#  '',
#  'o',
#  'n',
#  'S',
#  '.',
#  '',
#  '5',
#  '2',
#  '4',
#  '2',
#  'T',
#  'o',
#  '',
#  'p',
#  'r',
#  'e',
#  'v',
#  'e',
#  'n',
#  't',
#  '',
#  '',
#  'n',
#  't',
#  'e',
#  'r',
#  'n',
#  '',
#  't',
#  '',
#  'o',
#  'n',
#  '',
#  'l',
#  '',
#  'v',
#  '',
#  'o',
#  'l',
#  'e',
#  'n',
#  'c',
#  'e',
#  '',
#  '',
#  'g',
#  '',
#  '',
#  'n',
#  's',
#  't',
#  '',
#  'w',
#  'o',
#  'm',
#  'e',
#  'n',
#  ',',
#  '',
#  '',
#  'n',
#  'd',
#  '',
#  'f',
#  'o',
#  'r',
#  '',
#  'o',
#  't',
#  'h',
#  'e',
#  'r',
#  'p',
#  'u',
#  'r',
#  'p',
#  'o',
#  's',
#  'e',
#  's',
#  '.',
#  '',
#  '',
#  'N',
#  '',
#  'T',
#  'H',
#  'E',
#  '',
#  'S',
#  'E',
#  'N',
#  '',
#  'T',
#  'E',
#  '',
#  'O',
#  'F',
#  '',
#  'T',
#  'H',
#  'E',
#  '',
#  'U',
#  'N',
#  '',
#  'T',
#  'E',
#  'D',
#  '',
#  'S',
#  'T',
#  '',
#  'T',
#  'E',
#  'S',
#  '',
#  'D',
#  'e',
#  'c',
#  'e',
#  'm',
#  'b',
#  'e',
#  'r',
#  '',
#  '1',
#  '3',
#  ',',
#  '',
#  '2',
#  '0',
#  '2',
#  '2',
#  'M',
#  'r',
#  's',
#  '.',
#  '',
#  'S',
#  'h',
#  '',
#  'h',
#  'e',
#  'e',
#  'n',
#  '',
#  '(',
#  'f',
#  'o',
#  'r',
#  '',
#  'h',
#  'e',
#  'r',
#  's',
#  'e',
#  'l',
#  'f',
#  '',
#  '',
#  'n',
#  'd',
#  '',
#  'M',
#  's',
#  '.',
#  '',
#  'C',
#  'o',
#  'l',
#  'l',
#  '',
#  'n',
#  's',
#  ')',
#  '',
#  '',
#  'n',
#  't',
#  'r',
#  'o',
#  'd',
#  'u',
#  'c',
#  'e',
#  'd',
#  '',
#  't',
#  'h',
#  'e',
#  '',
#  'f',
#  'o',
#  'l',
#  'l',
#  'o',
#  'w',
#  '',
#  'n',
#  'g',
#  '',
#  'b',
#  '',
#  'l',
#  'l',
#  ';',
#  '',
#  'w',
#  'h',
#  '',
#  'c',
#  'h',
#  '',
#  'w',
#  '',
#  's',
#  '',
#  'r',
#  'e',
#  '',
#  'd',
#  '',
#  't',
#  'w',
#  '',
#  'c',
#  'e',
#  '',
#  '',
#  'n',
#  'd',
#  '',
#  'r',
#  'e',
#  'f',
#  'e',
#  'r',
#  'r',
#  'e',
#  'd',
#  '',
#  't',
#  'o',
#  '',
#  't',
#  'h',
#  'e',
#  '',
#  'C',
#  'o',
#  'm',
#  'm',
#  '',
#  't',
#  't',
#  'e',
#  'e',
#  '',
#  'o',
#  'n',
#  '',
#  'F',
#  'o',
#  'r',
#  'e',
#  '',
#  'g',
#  'n',
#  'R',
#  'e',
#  'l',
#  '',
#  't',
#  '',
#  'o',
#  'n',
#  's',
#  '',
#  '',
#  '',
#  'B',
#  '',
#  'L',
#  'L',
#  '',
#  'T',
#  'o',
#  '',
#  'p',
#  'r',
#  'e',
#  'v',
#  'e',
#  'n',
#  't',
#  '',
#  '',
#  'n',
#  't',
#  'e',
#  'r',
#  'n',
#  '',
#  't',
#  '',
#  'o',
#  'n',
#  '',
#  'l',
#  '',
#  'v',
#  '',
#  'o',
#  'l',
#  'e',
#  'n',
#  'c',
#  'e',
#  '',
#  '',
#  'g',
#  '',
#  '',
#  'n',
#  's',
#  't',
#  '',
#  'w',
#  'o',
#  'm',
#  'e',
#  'n',
#  ',',
#  '',
#  '',
#  'n',
#  'd',
#  '',
#  'f',
#  'o',
#  'r',
#  '',
#  'o',
#  't',
#  'h',
#  'e',
#  'r',
#  'p',
#  'u',
#  'r',
#  'p',
#  'o',
#  's',
#  'e',
#  's',
#  '.',
#  'B',
#  'e',
#  '',
#  '',
#  't',
#  '',
#  'e',
#  'n',
#  '',
#  'c',
#  't',
#  'e',
#  'd',
#  '',
#  'b',
#  'y',
#  '',
#  't',
#  'h',
#  'e',
#  '',
#  'S',
#  'e',
#  'n',
#  '',
#  't',
#  'e',
#  '',
#  '',
#  'n',
#  'd',
#  '',
#  'H',
#  'o',
#  'u',
#  's',
#  'e',
#  '',
#  'o',
#  'f',
#  '',
#  'R',
#  'e',
#  'p',
#  'r',
#  'e',
#  's',
#  'e',
#  'n',
#  't',
#  '',
#  't',
#  '',
#  'v',
#  'e',
#  's',
#  '',
#  'o',
#  'f',
#  '',
#  't',
#  'h',
#  'e',
#  '',
#  'U',
#  'n',
#  '',
#  't',
#  'e',
#  'd',
#  '',
#  'S',
#  't',
#  '',
#  't',
#  'e',
#  's',
#  '',
#  'o',
#  'f',
#  '',
#  '',
#  'm',
#  'e',
#  'r',
#  '',
#  'c',
#  '',
#  '',
#  '',
#  'n',
#  '',
#  'C',
#  'o',
#  'n',
#  'g',
#  'r',
#  'e',
#  's',
#  's',
#  '',
#  '',
#  's',
#  's',
#  'e',
#  'm',
#  'b',
#  'l',
#  'e',
#  'd',
#  ',',
#  'S',
#  'E',
#  'C',
#  'T',
#  '',
#  'O',
#  'N',
#  '',
#  '1',
#  '.',
#  '',
#  'S',
#  'H',
#  'O',
#  'R',
#  'T',
#  '',
#  'T',
#  '',
#  'T',
#  'L',
#  'E',
#  ';',
#  '',
#  'T',
#  '',
#  'B',
#  'L',
#  'E',
#  '',
#  'O',
#  'F',
#  '',
#  'C',
#  'O',
#  'N',
#  'T',
#  'E',
#  'N',
#  'T',
#  'S',
#  '.',
#  '(',
#  '',
#  ')',
#  '',
#  'S',
#  'h',
#  'o',
#  'r',
#  't',
#  '',
#  'T',
#  '',
#  't',
#  'l',
#  'e',
#  ';',
#  '',
#  'T',
#  '',
#  'b',
#  'l',
#  'e',
#  '',
#  'o',
#  'f',
#  '',
#  'C',
#  'o',
#  'n',
#  't',
#  'e',
#  'n',
#  't',
#  's',
#  '.',
#  '-',
#  '-',
#  'T',
#  'h',
#  '',
#  's',
#  '',
#  '',
#  'c',
#  't',
#  '',
#  'm',
#  '',
#  'y',
#  '',
#  'b',
#  'e',
#  '',
#  'c',
#  '',
#  't',
#  'e',
#  'd',
#  '',
#  '',
#  's',
#  '',
#  't',
#  'h',
#  'e',
#  '',
#  '`',
#  '`',
#  '',
#  'n',
#  't',
#  'e',
#  'r',
#  'n',
#  '',
#  't',
#  '',
#  'o',
#  'n',
#  '',
#  'l',
#  '',
#  'V',
#  '',
#  'o',
#  'l',
#  'e',
#  'n',
#  'c',
#  'e',
#  '',
#  '',
#  'g',
#  '',
#  '',
#  'n',
#  's',
#  't',
#  '',
#  'W',
#  'o',
#  'm',
#  'e',
#  'n',
#  '',
#  '',
#  'c',
#  't',
#  '',
#  'o',
#  'f',
#  '',
#  '2',
#  '0',
#  '2',
#  '2',
#  "'",
#  "'",
#  '.',
#  '(',
#  'b',
#  ')',
#  '',
#  'T',
#  '',
#  'b',
#  'l',
#  'e',
#  '',
#  'o',
#  'f',
#  '',
#  'C',
#  'o',
#  'n',
#  't',
#  'e',
#  'n',
#  't',
#  's',
#  '.',
#  '-',
#  '-',
#  'T',
#  'h',
#  'e',
#  '',
#  't',
#  '',
#  'b',
#  'l',
#  'e',
#  '',
#  'o',
#  'f',
#  '',
#  'c',
#  'o',
#  'n',
#  't',
#  'e',
#  'n',
#  't',
#  's',
#  '',
#  'f',
#  'o',
#  'r',
#  '',
#  't',
#  'h',
#  '',
#  's',
#  '',
#  '',
#  'c',
#  't',
#  '',
#  '',
#  's',
#  '',
#  '',
#  's',
#  '',
#  'f',
#  'o',
#  'l',
#  'l',
#  'o',
#  'w',
#  's',
#  ':',
#  'S',
#  'e',
#  'c',
#  '.',
#  '',
#  '1',
#  '.',
#  '',
#  'S',
#  'h',
#  'o',
#  'r',
#  't',
#  '',
#  't',
#  '',
#  't',
#  'l',
#  'e',
#  ';',
#  '',
#  't',
#  '',
#  'b',
#  'l',
#  'e',
#  '',
#  'o',
#  'f',
#  '',
#  'c',
#  'o',
#  'n',
#  't',
#  'e',
#  'n',
#  't',
#  's',
#  '.',
#  'S',
#  'e',
#  'c',
#  '.',
#  '',
#  '2',
#  '.',
#  '',
#  'F',
#  '',
#  'n',
#  'd',
#  '',
#  'n',
#  'g',
#  's',
#  '.',
#  'S',
#  'e',
#  'c',
#  '.',
#  '',
#  '3',
#  '.',
#  '',
#  'S',
#  't',
#  '',
#  't',
#  'e',
#  'm',
#  'e',
#  'n',
#  't',
#  '',
#  'o',
#  'f',
#  '',
#  'p',
#  'o',
#  'l',
#  '',
#  'c',
#  'y',
#  '.',
#  'T',
#  '',
#  'T',
#  'L',
#  'E',
#  '',
#  '',
#  '-',
#  '-',
#  'U',
#  'N',
#  '',
#  'T',
#  'E',
#  'D',
#  '',
#  'S',
#  'T',
#  '',
#  'T',
#  'E',
#  'S',
#  '',
#  'S',
#  'T',
#  'R',
#  '',
#  'T',
#  'E',
#  'G',
#  'Y',
#  '',
#  'T',
#  'O',
#  '',
#  'P',
#  'R',
#  'E',
#  'V',
#  'E',
#  'N',
#  'T',
#  '',
#  '',
#  'N',
#  'D',
#  '',
#  'R',
#  'E',
#  'S',
#  'P',
#  'O',
#  'N',
#  'D',
#  '',
#  'T',
#  'O',
#  '',
#  'G',
#  'E',
#  'N',
#  'D',
#  'E',
#  'R',
#  '-',
#  'B',
#  '',
#  'S',
#  'E',
#  'D',
#  'V',
#  ...]
