# %% [markdown]
# # dataframes

# %%
import pandas as pd # for working with tabular (spreadsheet) data
import requests # for loading up the dataset from github

# %% [markdown]
# We will first work in our data in the form of a dataframe. A dataframe is a two-dimensional data structure that holds data in a table with rows and columns. It is the same as a dictionary or `dict` type of data.

# %%
# pulling up a CSV of search results from congress.gov 
# if this code doesn't work, download the csv from link 
# below, and upload it to your google colab space
# https://bit.ly/congress_csv

df = pd.read_csv('https://bit.ly/congress_dirty_csv')

# %%
# taking a peak at the DF

df
# Out:
#     Legislation Number                                                URL  \
# 0            H.R. 1112  https://www.congress.gov/bill/118th-congress/h...
# 1               S. 435  https://www.congress.gov/bill/118th-congress/s...
# 2           H.Res. 886  https://www.congress.gov/bill/118th-congress/h...
# 3           S.Res. 464  https://www.congress.gov/bill/118th-congress/s...
# 4           H.Res. 269  https://www.congress.gov/bill/118th-congress/h...
# ..                 ...                                                ...
# 281                NaN                                                NaN
# 282                NaN                                                NaN
# 283                NaN                                                NaN
# 284                NaN                                                NaN
# 285                NaN                                                NaN
#
#                        Congress  \
# 0    118th Congress (2023-2024)
# 1    118th Congress (2023-2024)
# 2    118th Congress (2023-2024)
# 3    118th Congress (2023-2024)
# 4    118th Congress (2023-2024)
# ..                          ...
# 281                         NaN
# 282                         NaN
# 283                         NaN
# 284                         NaN
# 285                         NaN
#
#                                                  Title  \
# 0              Ensuring Military Readiness Act of 2023
# 1              Ensuring Military Readiness Act of 2023
# 2    Supporting the goals and principles of Transge...
# 3    A resolution supporting the goals and principl...
# 4    Recognizing that it is the duty of the Federal...
# ..                                                 ...
# 281                                                NaN
# 282                                                NaN
# 283                                                NaN
# 284                                                NaN
# 285                                                NaN
#
#                             Sponsor Party of Sponsor Date of Introduction  \
# 0          Banks, Jim [Rep.-R-IN-3]       Republican              2/21/23
# 1          Rubio, Marco [Sen.-R-FL]       Republican              2/15/23
# 2    Jayapal, Pramila [Rep.-D-WA-7]       Democratic             11/21/23
# 3      Hirono, Mazie K. [Sen.-D-HI]       Democratic             11/15/23
# 4    Jayapal, Pramila [Rep.-D-WA-7]       Democratic              3/30/23
# ..                              ...              ...                  ...
# 281                             NaN              NaN                  NaN
# 282                             NaN              NaN                  NaN
# 283                             NaN              NaN                  NaN
# 284                             NaN              NaN                  NaN
# 285                             NaN              NaN                  NaN
#
#                                             Committees  \
# 0                               House - Armed Services
# 1                              Senate - Armed Services
# 2                                    House - Judiciary
# 3                                   Senate - Judiciary
# 4    House - Judiciary, Education and the Workforce...
# ..                                                 ...
# 281                                                NaN
# 282                                                NaN
# 283                                                NaN
# 284                                                NaN
# 285                                                NaN
#
#                                          Latest Action Latest Action Date  \
# 0    Referred to the House Committee on Armed Servi...            2/21/23
# 1    Read twice and referred to the Committee on Ar...            2/15/23
# 2    Referred to the House Committee on the Judiciary.           11/21/23
# 3                    Star Print ordered on resolution.            12/4/23
# 4    Sponsor introductory remarks on measure. (CR H...            4/19/23
# ..                                                 ...                ...
# 281                                                NaN                NaN
# 282                                                NaN                NaN
# 283                                                NaN                NaN
# 284                                                NaN                NaN
# 285                                                NaN                NaN
#
#      ... Related Bill.211 Related Bill.212 Related Bill.213  \
# 0    ...              NaN              NaN              NaN
# 1    ...              NaN              NaN              NaN
# 2    ...              NaN              NaN              NaN
# 3    ...              NaN              NaN              NaN
# 4    ...              NaN              NaN              NaN
# ..   ...              ...              ...              ...
# 281  ...              NaN              NaN              NaN
# 282  ...              NaN              NaN              NaN
# 283  ...              NaN              NaN              NaN
# 284  ...              NaN              NaN              NaN
# 285  ...              NaN              NaN              NaN
#
#                                         Latest Summary Amends Bill  \
# 0     <p><b>Ensuring Military Readiness Act of 2023...         NaN
# 1     <p><b>Ensuring Military Readiness Act of 2023...         NaN
# 2     <p>This resolution expresses support for the ...         NaN
# 3     <p>This resolution expresses support for the ...         NaN
# 4     <p>This resolution expresses support for impl...         NaN
# ..                                                 ...         ...
# 281                                                NaN         NaN
# 282                                                NaN         NaN
# 283                                                NaN         NaN
# 284                                                NaN         NaN
# 285                                                NaN         NaN
#
#     Date Offered Date Submitted Date Proposed  \
# 0            NaN            NaN           NaN
# 1            NaN            NaN           NaN
# 2            NaN            NaN           NaN
# 3            NaN            NaN           NaN
# 4            NaN            NaN           NaN
# ..           ...            ...           ...
# 281          NaN            NaN           NaN
# 282          NaN            NaN           NaN
# 283          NaN            NaN           NaN
# 284          NaN            NaN           NaN
# 285          NaN            NaN           NaN
#
#                                Amendment Text (Latest) Amends Amendment
# 0                                                  NaN              NaN
# 1                                                  NaN              NaN
# 2                                                  NaN              NaN
# 3                                                  NaN              NaN
# 4                                                  NaN              NaN
# ..                                                 ...              ...
# 281  I welcome that discussion.\n  Mr. Chair, I yie...              NaN
# 282  biotechnology equipment or service produced or...              NaN
# 283  United States assistance has \n     been provi...              NaN
# 284  Director of National Intelligence, shall submi...              NaN
# 285  demanded.\n  A recorded vote was ordered.\n  T...              NaN
#
# [286 rows x 650 columns]

# %% [markdown]
# What is a `dataframe` object?
# -

# %% [markdown]
# ## viewing data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 286 entries, 0 to 285
# Columns: 650 entries, Legislation Number to Amends Amendment
# dtypes: float64(4), object(646)
# memory usage: 1.4+ MB

# %%
df.head()
# Out:
#   Legislation Number                                                URL  \
# 0          H.R. 1112  https://www.congress.gov/bill/118th-congress/h...
# 1             S. 435  https://www.congress.gov/bill/118th-congress/s...
# 2         H.Res. 886  https://www.congress.gov/bill/118th-congress/h...
# 3         S.Res. 464  https://www.congress.gov/bill/118th-congress/s...
# 4         H.Res. 269  https://www.congress.gov/bill/118th-congress/h...
#
#                      Congress  \
# 0  118th Congress (2023-2024)
# 1  118th Congress (2023-2024)
# 2  118th Congress (2023-2024)
# 3  118th Congress (2023-2024)
# 4  118th Congress (2023-2024)
#
#                                                Title  \
# 0            Ensuring Military Readiness Act of 2023
# 1            Ensuring Military Readiness Act of 2023
# 2  Supporting the goals and principles of Transge...
# 3  A resolution supporting the goals and principl...
# 4  Recognizing that it is the duty of the Federal...
#
#                           Sponsor Party of Sponsor Date of Introduction  \
# 0        Banks, Jim [Rep.-R-IN-3]       Republican              2/21/23
# 1        Rubio, Marco [Sen.-R-FL]       Republican              2/15/23
# 2  Jayapal, Pramila [Rep.-D-WA-7]       Democratic             11/21/23
# 3    Hirono, Mazie K. [Sen.-D-HI]       Democratic             11/15/23
# 4  Jayapal, Pramila [Rep.-D-WA-7]       Democratic              3/30/23
#
#                                           Committees  \
# 0                             House - Armed Services
# 1                            Senate - Armed Services
# 2                                  House - Judiciary
# 3                                 Senate - Judiciary
# 4  House - Judiciary, Education and the Workforce...
#
#                                        Latest Action Latest Action Date  ...  \
# 0  Referred to the House Committee on Armed Servi...            2/21/23  ...
# 1  Read twice and referred to the Committee on Ar...            2/15/23  ...
# 2  Referred to the House Committee on the Judiciary.           11/21/23  ...
# 3                  Star Print ordered on resolution.            12/4/23  ...
# 4  Sponsor introductory remarks on measure. (CR H...            4/19/23  ...
#
#   Related Bill.211 Related Bill.212 Related Bill.213  \
# 0              NaN              NaN              NaN
# 1              NaN              NaN              NaN
# 2              NaN              NaN              NaN
# 3              NaN              NaN              NaN
# 4              NaN              NaN              NaN
#
#                                       Latest Summary Amends Bill Date Offered  \
# 0   <p><b>Ensuring Military Readiness Act of 2023...         NaN          NaN
# 1   <p><b>Ensuring Military Readiness Act of 2023...         NaN          NaN
# 2   <p>This resolution expresses support for the ...         NaN          NaN
# 3   <p>This resolution expresses support for the ...         NaN          NaN
# 4   <p>This resolution expresses support for impl...         NaN          NaN
#
#   Date Submitted Date Proposed Amendment Text (Latest) Amends Amendment
# 0            NaN           NaN                     NaN              NaN
# 1            NaN           NaN                     NaN              NaN
# 2            NaN           NaN                     NaN              NaN
# 3            NaN           NaN                     NaN              NaN
# 4            NaN           NaN                     NaN              NaN
#
# [5 rows x 650 columns]

# %%
df.tail()
# Out:
#     Legislation Number  URL Congress Title Sponsor Party of Sponsor  \
# 281                NaN  NaN      NaN   NaN     NaN              NaN
# 282                NaN  NaN      NaN   NaN     NaN              NaN
# 283                NaN  NaN      NaN   NaN     NaN              NaN
# 284                NaN  NaN      NaN   NaN     NaN              NaN
# 285                NaN  NaN      NaN   NaN     NaN              NaN
#
#     Date of Introduction Committees Latest Action Latest Action Date  ...  \
# 281                  NaN        NaN           NaN                NaN  ...
# 282                  NaN        NaN           NaN                NaN  ...
# 283                  NaN        NaN           NaN                NaN  ...
# 284                  NaN        NaN           NaN                NaN  ...
# 285                  NaN        NaN           NaN                NaN  ...
#
#     Related Bill.211 Related Bill.212 Related Bill.213 Latest Summary  \
# 281              NaN              NaN              NaN            NaN
# 282              NaN              NaN              NaN            NaN
# 283              NaN              NaN              NaN            NaN
# 284              NaN              NaN              NaN            NaN
# 285              NaN              NaN              NaN            NaN
#
#     Amends Bill Date Offered Date Submitted Date Proposed  \
# 281         NaN          NaN            NaN           NaN
# 282         NaN          NaN            NaN           NaN
# 283         NaN          NaN            NaN           NaN
# 284         NaN          NaN            NaN           NaN
# 285         NaN          NaN            NaN           NaN
#
#                                Amendment Text (Latest) Amends Amendment
# 281  I welcome that discussion.\n  Mr. Chair, I yie...              NaN
# 282  biotechnology equipment or service produced or...              NaN
# 283  United States assistance has \n     been provi...              NaN
# 284  Director of National Intelligence, shall submi...              NaN
# 285  demanded.\n  A recorded vote was ordered.\n  T...              NaN
#
# [5 rows x 650 columns]

# %% [markdown]
# ## cleaning rows & columns

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [Legislation Number, URL, Congress, Title, Sponsor, Party of Sponsor, Date of Introduction, Committees, Latest Action, Latest Action Date, Cosponsor, Cosponsor.1, Cosponsor.2, Cosponsor.3, Cosponsor.4, Cosponsor.5, Cosponsor.6, Cosponsor.7, Cosponsor.8, Cosponsor.9, Cosponsor.10, Cosponsor.11, Cosponsor.12, Cosponsor.13, Cosponsor.14, Cosponsor.15, Cosponsor.16, Cosponsor.17, Cosponsor.18, Cosponsor.19, Cosponsor.20, Cosponsor.21, Cosponsor.22, Cosponsor.23, Cosponsor.24, Cosponsor.25, Cosponsor.26, Cosponsor.27, Cosponsor.28, Cosponsor.29, Cosponsor.30, Cosponsor.31, Cosponsor.32, Cosponsor.33, Cosponsor.34, Cosponsor.35, Cosponsor.36, Cosponsor.37, Cosponsor.38, Cosponsor.39, Cosponsor.40, Cosponsor.41, Cosponsor.42, Cosponsor.43, Cosponsor.44, Cosponsor.45, Cosponsor.46, Cosponsor.47, Cosponsor.48, Cosponsor.49, Cosponsor.50, Cosponsor.51, Cosponsor.52, Cosponsor.53, Cosponsor.54, Cosponsor.55, Cosponsor.56, Cosponsor.57, Cosponsor.58, Cosponsor.59, Cosponsor.60, Cosponsor.61, Cosponsor.62, Cosponsor.63, Cosponsor.64, Cosponsor.65, Cosponsor.66, Cosponsor.67, Cosponsor.68, Cosponsor.69, Cosponsor.70, Cosponsor.71, Cosponsor.72, Cosponsor.73, Cosponsor.74, Cosponsor.75, Cosponsor.76, Cosponsor.77, Cosponsor.78, Cosponsor.79, Cosponsor.80, Cosponsor.81, Cosponsor.82, Cosponsor.83, Cosponsor.84, Cosponsor.85, Cosponsor.86, Cosponsor.87, Cosponsor.88, Cosponsor.89, ...]
# Index: []
#
# [0 rows x 650 columns]

# %%
df
# Out:
#     Legislation Number                                                URL  \
# 0            H.R. 1112  https://www.congress.gov/bill/118th-congress/h...
# 1               S. 435  https://www.congress.gov/bill/118th-congress/s...
# 2           H.Res. 886  https://www.congress.gov/bill/118th-congress/h...
# 3           S.Res. 464  https://www.congress.gov/bill/118th-congress/s...
# 4           H.Res. 269  https://www.congress.gov/bill/118th-congress/h...
# ..                 ...                                                ...
# 281                NaN                                                NaN
# 282                NaN                                                NaN
# 283                NaN                                                NaN
# 284                NaN                                                NaN
# 285                NaN                                                NaN
#
#                        Congress  \
# 0    118th Congress (2023-2024)
# 1    118th Congress (2023-2024)
# 2    118th Congress (2023-2024)
# 3    118th Congress (2023-2024)
# 4    118th Congress (2023-2024)
# ..                          ...
# 281                         NaN
# 282                         NaN
# 283                         NaN
# 284                         NaN
# 285                         NaN
#
#                                                  Title  \
# 0              Ensuring Military Readiness Act of 2023
# 1              Ensuring Military Readiness Act of 2023
# 2    Supporting the goals and principles of Transge...
# 3    A resolution supporting the goals and principl...
# 4    Recognizing that it is the duty of the Federal...
# ..                                                 ...
# 281                                                NaN
# 282                                                NaN
# 283                                                NaN
# 284                                                NaN
# 285                                                NaN
#
#                             Sponsor Party of Sponsor Date of Introduction  \
# 0          Banks, Jim [Rep.-R-IN-3]       Republican              2/21/23
# 1          Rubio, Marco [Sen.-R-FL]       Republican              2/15/23
# 2    Jayapal, Pramila [Rep.-D-WA-7]       Democratic             11/21/23
# 3      Hirono, Mazie K. [Sen.-D-HI]       Democratic             11/15/23
# 4    Jayapal, Pramila [Rep.-D-WA-7]       Democratic              3/30/23
# ..                              ...              ...                  ...
# 281                             NaN              NaN                  NaN
# 282                             NaN              NaN                  NaN
# 283                             NaN              NaN                  NaN
# 284                             NaN              NaN                  NaN
# 285                             NaN              NaN                  NaN
#
#                                             Committees  \
# 0                               House - Armed Services
# 1                              Senate - Armed Services
# 2                                    House - Judiciary
# 3                                   Senate - Judiciary
# 4    House - Judiciary, Education and the Workforce...
# ..                                                 ...
# 281                                                NaN
# 282                                                NaN
# 283                                                NaN
# 284                                                NaN
# 285                                                NaN
#
#                                          Latest Action Latest Action Date  \
# 0    Referred to the House Committee on Armed Servi...            2/21/23
# 1    Read twice and referred to the Committee on Ar...            2/15/23
# 2    Referred to the House Committee on the Judiciary.           11/21/23
# 3                    Star Print ordered on resolution.            12/4/23
# 4    Sponsor introductory remarks on measure. (CR H...            4/19/23
# ..                                                 ...                ...
# 281                                                NaN                NaN
# 282                                                NaN                NaN
# 283                                                NaN                NaN
# 284                                                NaN                NaN
# 285                                                NaN                NaN
#
#      ... Related Bill.211 Related Bill.212 Related Bill.213  \
# 0    ...              NaN              NaN              NaN
# 1    ...              NaN              NaN              NaN
# 2    ...              NaN              NaN              NaN
# 3    ...              NaN              NaN              NaN
# 4    ...              NaN              NaN              NaN
# ..   ...              ...              ...              ...
# 281  ...              NaN              NaN              NaN
# 282  ...              NaN              NaN              NaN
# 283  ...              NaN              NaN              NaN
# 284  ...              NaN              NaN              NaN
# 285  ...              NaN              NaN              NaN
#
#                                         Latest Summary Amends Bill  \
# 0     <p><b>Ensuring Military Readiness Act of 2023...         NaN
# 1     <p><b>Ensuring Military Readiness Act of 2023...         NaN
# 2     <p>This resolution expresses support for the ...         NaN
# 3     <p>This resolution expresses support for the ...         NaN
# 4     <p>This resolution expresses support for impl...         NaN
# ..                                                 ...         ...
# 281                                                NaN         NaN
# 282                                                NaN         NaN
# 283                                                NaN         NaN
# 284                                                NaN         NaN
# 285                                                NaN         NaN
#
#     Date Offered Date Submitted Date Proposed  \
# 0            NaN            NaN           NaN
# 1            NaN            NaN           NaN
# 2            NaN            NaN           NaN
# 3            NaN            NaN           NaN
# 4            NaN            NaN           NaN
# ..           ...            ...           ...
# 281          NaN            NaN           NaN
# 282          NaN            NaN           NaN
# 283          NaN            NaN           NaN
# 284          NaN            NaN           NaN
# 285          NaN            NaN           NaN
#
#                                Amendment Text (Latest) Amends Amendment
# 0                                                  NaN              NaN
# 1                                                  NaN              NaN
# 2                                                  NaN              NaN
# 3                                                  NaN              NaN
# 4                                                  NaN              NaN
# ..                                                 ...              ...
# 281  I welcome that discussion.\n  Mr. Chair, I yie...              NaN
# 282  biotechnology equipment or service produced or...              NaN
# 283  United States assistance has \n     been provi...              NaN
# 284  Director of National Intelligence, shall submi...              NaN
# 285  demanded.\n  A recorded vote was ordered.\n  T...              NaN
#
# [286 rows x 650 columns]

# %%
df = df[df['Legislation Number'].notna()]

# %%
df.tail()
# Out:
#     Legislation Number                                                URL  \
# 260        H.Amdt. 195  https://www.congress.gov/amendment/118th-congr...
# 264        H.Amdt. 193  https://www.congress.gov/amendment/118th-congr...
# 268        H.Amdt. 256  https://www.congress.gov/amendment/118th-congr...
# 274        H.Amdt. 257  https://www.congress.gov/amendment/118th-congr...
# 280        H.Amdt. 255  https://www.congress.gov/amendment/118th-congr...
#
#                        Congress  \
# 260  118th Congress (2023-2024)
# 264  118th Congress (2023-2024)
# 268  118th Congress (2023-2024)
# 274  118th Congress (2023-2024)
# 280  118th Congress (2023-2024)
#
#                                                  Title  \
# 260  An amendment numbered 6 printed in Part A of H...
# 264  An amendment numbered 4 printed in Part A of H...
# 268  An amendment numbered 66 printed in House Repo...
# 274  An amendment comprised of the following amendm...
# 280  An amendment numbered 64 printed in House Repo...
#
#                             Sponsor Party of Sponsor Date of Introduction  \
# 260         Good, Bob [Rep.-R-VA-5]       Republican                  NaN
# 264       Biggs, Andy [Rep.-R-AZ-5]       Republican                  NaN
# 268  Davidson, Warren [Rep.-R-OH-8]       Republican                  NaN
# 274   Rogers, Mike D. [Rep.-R-AL-3]       Republican                  NaN
# 280        Roy, Chip [Rep.-R-TX-21]       Republican                  NaN
#
#     Committees                                      Latest Action  \
# 260        NaN  On agreeing to the Good (VA) amendment (A006) ...
# 264        NaN  On agreeing to the Biggs amendment (A004) Fail...
# 268        NaN  On agreeing to the Davidson amendment (A041) A...
# 274        NaN  On agreeing to the Rogers (AL) amendments (A04...
# 280        NaN  On agreeing to the Roy amendment (A040) Agreed...
#
#     Latest Action Date  ... Related Bill.211 Related Bill.212  \
# 260            6/14/23  ...              NaN              NaN
# 264            6/14/23  ...              NaN              NaN
# 268            7/14/23  ...              NaN              NaN
# 274            7/14/23  ...              NaN              NaN
# 280            7/14/23  ...              NaN              NaN
#
#     Related Bill.213 Latest Summary Amends Bill Date Offered Date Submitted  \
# 260              NaN            NaN    H.R. 277      6/14/23            NaN
# 264              NaN            NaN    H.R. 277      6/14/23            NaN
# 268              NaN            NaN   H.R. 2670      7/14/23            NaN
# 274              NaN            NaN   H.R. 2670      7/14/23            NaN
# 280              NaN            NaN   H.R. 2670      7/14/23            NaN
#
#     Date Proposed                            Amendment Text (Latest)  \
# 260           NaN  [Pages H2902-H2916]\nFrom the Congressional Re...
# 264           NaN  [Pages H2902-H2916]\nFrom the Congressional Re...
# 268           NaN  [Pages H3581-H3600]\nFrom the Congressional Re...
# 274           NaN  [Pages H3581-H3600]\nFrom the Congressional Re...
# 280           NaN  [Pages H3581-H3600]\nFrom the Congressional Re...
#
#     Amends Amendment
# 260              NaN
# 264              NaN
# 268              NaN
# 274              NaN
# 280              NaN
#
# [5 rows x 650 columns]

# %%
# notice that we have 148 rows, but our index goes up to 280

# %%
df = df.dropna(axis=1, how='all')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 286 entries, 0 to 285
# Columns: 648 entries, Legislation Number to Amendment Text (Latest)
# dtypes: float64(2), object(646)
# memory usage: 1.4+ MB

# %%
df.columns
