# %% [markdown]
# # cleaning our text
# In this section we will clean the bill text that we scraped from the last section. For those of you who are

# %% [markdown]
# ## functions
#
# How do you write a function?
#
# ```
# def add(x, y):
#     print(x + y)
# ```
#
# How do you call a function?
#
# ```
# add(5, 7)
# ```
